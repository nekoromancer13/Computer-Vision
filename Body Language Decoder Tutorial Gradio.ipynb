# %%
# %pip install xgboost
# %pip install scikit-learn

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
import pandas as pd
import csv
import os
import numpy as np
import xgboost as xgb
from sklearn.utils import resample
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix
import pickle
from sklearn.model_selection import GridSearchCV

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions
dataset_train = pd.read_csv('./train.csv')
dataset_test = pd.read_csv('./test.csv')
#preprocessing

#correcting video directory
dataset_train['clip_path'] = dataset_train['clip_path'].apply(lambda x: '.' + x)
dataset_test['clip_path'] = dataset_test['clip_path'].apply(lambda x: '.' + x)



#Downsampling to make the dataset balanced and normally distributed

def downsample(df, min_samples_per_class):
    downsampled_dfs = []

    # Get the unique classes
    classes = df['label'].unique()

    for cls in classes:
        class_df = df[df['label'] == cls]

        # Ensure the number of samples doesn't exceed available data
        n_samples = min(min_samples_per_class, len(class_df))

        # Downsample the class to the specified number of samples
        downsampled_class_df = resample(
            class_df,
            replace=False,  # sample without replacement
            n_samples=n_samples,  # to match the minimum class size
            random_state=42  # for reproducibility
        )
        downsampled_dfs.append(downsampled_class_df)

    return pd.concat(downsampled_dfs)

dataset_train = downsample(dataset_train, 40)
dataset_test = downsample(dataset_test,40)

# %%
print(dataset_train['label'].value_counts())
print(dataset_test['label'].value_counts())
# Out:
# label
# Swing                40
# PushUps              40
# Hammering            40
# TrampolineJumping    40
# PizzaTossing         40
#                      ..
# PlayingDhol          40
# Archery              40
# Punch                40
# VolleyballSpiking    40
# Diving               40
# Name: count, Length: 101, dtype: int64
# label
# Basketball           34
# TennisSwing          21
# CricketShot          21
# BoxingPunchingBag    21
# PlayingDhol          21
#                      ..
# Skijet               13
# UnevenBars           13
# PushUps              13
# TaiChi               13
# PlayingViolin        13
# Name: count, Length: 101, dtype: int64

# %%
def process_videos(dataset, set_name, amount):
    # Initialize the Holistic model
    with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:

        landmarks = ['class']
        for val in range(1, 33+1):
            landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
        with open(f'{set_name}_coords.csv', mode='w', newline='') as f:
            csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(landmarks)

        for i in range(len(dataset[:amount])):
            video_path = dataset['clip_path'].iloc[i]
            class_name = dataset['label'].iloc[i]
            print(f"Processing {set_name} video file: {video_path}")

            cap = cv2.VideoCapture(video_path)

            if not cap.isOpened():
                print(f"Error: Could not open video file {video_path}")
                continue  # Skip to the next video file if there is an error

            frame_count = 0

            while cap.isOpened():
                ret, frame = cap.read()
                frame_count += 1

                if not ret or frame is None:
                    print(f"Error: Could not read frame {frame_count} from {video_path}")
                    break

                try:
                    # Resize the frame to a fixed size for consistency
                    frame = cv2.resize(frame, (640, 480))

                    # Check the frame's data type and convert to uint8 if necessary
                    if frame.dtype != 'uint8':
                        frame = (frame * 255).astype('uint8')

                    # Apply Median Blur to reduce noise
                    frame = cv2.medianBlur(frame, 5)

                    # Convert to grayscale for histogram equalization
                    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

                    # Apply Histogram Equalization
                    equalized_frame = cv2.equalizeHist(gray_frame)

                    # Convert back to BGR
                    frame = cv2.cvtColor(equalized_frame, cv2.COLOR_GRAY2BGR)

                    # Recolor Feed (convert BGR to RGB)
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                except cv2.error as e:
                    print(f"Error during preprocessing at frame {frame_count}: {e}")
                    break

                image.flags.writeable = False

                # Make Detections
                results = holistic.process(image)
                image.flags.writeable = True
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

                # Draw pose landmarks
                if results.pose_landmarks:  # Check if pose landmarks are present
                    mp_drawing.draw_landmarks(
                        image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                        mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                        mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                    )

                    # Export coordinates
                    try:
                        # Extract Pose landmarks
                        pose = results.pose_landmarks.landmark
                        pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                        # Append class name
                        pose_row.insert(0, class_name)

                        # Export to CSV
                        with open(f'{set_name}_coords.csv', mode='a', newline='') as f:
                            csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                            csv_writer.writerow(pose_row)

                    except Exception as e:
                        print(f"Error extracting or writing pose landmarks at frame {frame_count}: {e}")

            cap.release()

# Process training videos
process_videos(dataset_train, 'train', 140)

# Process testing videos
process_videos(dataset_test, 'test', 60)

cv2.destroyAllWindows()
# Out:
# Processing train video file: ./train/Swing/v_Swing_g15_c03.avi
# Error: Could not read frame 89 from ./train/Swing/v_Swing_g15_c03.avi
# Processing train video file: ./train/Swing/v_Swing_g15_c06.avi
# Error: Could not read frame 202 from ./train/Swing/v_Swing_g15_c06.avi
# Processing train video file: ./train/Swing/v_Swing_g14_c03.avi
# Error: Could not read frame 152 from ./train/Swing/v_Swing_g14_c03.avi
# Processing train video file: ./train/Swing/v_Swing_g01_c04.avi
# Error: Could not read frame 127 from ./train/Swing/v_Swing_g01_c04.avi
# Processing train video file: ./train/Swing/v_Swing_g05_c06.avi
# Error: Could not read frame 202 from ./train/Swing/v_Swing_g05_c06.avi
# Processing train video file: ./train/Swing/v_Swing_g14_c01.avi
# Error: Could not read frame 114 from ./train/Swing/v_Swing_g14_c01.avi
# Processing train video file: ./train/Swing/v_Swing_g11_c05.avi
# Error: Could not read frame 152 from ./train/Swing/v_Swing_g11_c05.avi
# Processing train video file: ./train/Swing/v_Swing_g09_c03.avi
# Error: Could not read frame 127 from ./train/Swing/v_Swing_g09_c03.avi
# Processing train video file: ./train/Swing/v_Swing_g14_c04.avi
# Error: Could not read frame 152 from ./train/Swing/v_Swing_g14_c04.avi
# Processing train video file: ./train/Swing/v_Swing_g05_c02.avi
# Error: Could not read frame 110 from ./train/Swing/v_Swing_g05_c02.avi
# Processing train video file: ./train/Swing/v_Swing_g22_c01.avi
# Error: Could not read frame 152 from ./train/Swing/v_Swing_g22_c01.avi
# Processing train video file: ./train/Swing/v_Swing_g14_c05.avi
# Error: Could not read frame 152 from ./train/Swing/v_Swing_g14_c05.avi
# Processing train video file: ./train/Swing/v_Swing_g07_c02.avi
# Error: Could not read frame 252 from ./train/Swing/v_Swing_g07_c02.avi
# Processing train video file: ./train/SkyDiving/v_SkyDiving_g21_c03.avi
# Error: Could not read frame 204 from ./train/SkyDiving/v_SkyDiving_g21_c03.avi
# Processing train video file: ./train/SkyDiving/v_SkyDiving_g02_c03.avi
# Error: Could not read frame 137 from ./train/SkyDiving/v_SkyDiving_g02_c03.avi
# Processing train video file: ./train/SkyDiving/v_SkyDiving_g15_c05.avi
# Error: Could not read frame 49 from ./train/SkyDiving/v_SkyDiving_g15_c05.avi
# Processing train video file: ./train/SkyDiving/v_SkyDiving_g22_c03.avi
# Error: Could not read frame 299 from ./train/SkyDiving/v_SkyDiving_g22_c03.avi
# Processing train video file: ./train/SkyDiving/v_SkyDiving_g21_c02.avi
# Error: Could not read frame 209 from ./train/SkyDiving/v_SkyDiving_g21_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g11_c03.avi
# Error: Could not read frame 419 from ./train/BreastStroke/v_BreastStroke_g11_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g14_c03.avi
# Error: Could not read frame 94 from ./train/BreastStroke/v_BreastStroke_g14_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g12_c03.avi
# Error: Could not read frame 177 from ./train/BreastStroke/v_BreastStroke_g12_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g21_c02.avi
# Error: Could not read frame 102 from ./train/BreastStroke/v_BreastStroke_g21_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g08_c02.avi
# Error: Could not read frame 214 from ./train/BreastStroke/v_BreastStroke_g08_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g13_c04.avi
# Error: Could not read frame 87 from ./train/BreastStroke/v_BreastStroke_g13_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g02_c03.avi
# Error: Could not read frame 98 from ./train/BreastStroke/v_BreastStroke_g02_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g14_c02.avi
# Error: Could not read frame 94 from ./train/BreastStroke/v_BreastStroke_g14_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g23_c03.avi
# Error: Could not read frame 336 from ./train/BreastStroke/v_BreastStroke_g23_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g19_c04.avi
# Error: Could not read frame 228 from ./train/BreastStroke/v_BreastStroke_g19_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g05_c02.avi
# Error: Could not read frame 226 from ./train/BreastStroke/v_BreastStroke_g05_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g13_c02.avi
# Error: Could not read frame 68 from ./train/BreastStroke/v_BreastStroke_g13_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g21_c01.avi
# Error: Could not read frame 102 from ./train/BreastStroke/v_BreastStroke_g21_c01.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g07_c01.avi
# Error: Could not read frame 261 from ./train/BreastStroke/v_BreastStroke_g07_c01.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g02_c04.avi
# Error: Could not read frame 262 from ./train/BreastStroke/v_BreastStroke_g02_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g18_c05.avi
# Error: Could not read frame 138 from ./train/BreastStroke/v_BreastStroke_g18_c05.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g06_c03.avi
# Error: Could not read frame 101 from ./train/BreastStroke/v_BreastStroke_g06_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g05_c04.avi
# Error: Could not read frame 334 from ./train/BreastStroke/v_BreastStroke_g05_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g15_c02.avi
# Error: Could not read frame 127 from ./train/BreastStroke/v_BreastStroke_g15_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g18_c02.avi
# Error: Could not read frame 117 from ./train/BreastStroke/v_BreastStroke_g18_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g08_c03.avi
# Error: Could not read frame 231 from ./train/BreastStroke/v_BreastStroke_g08_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g24_c01.avi
# Error: Could not read frame 118 from ./train/BreastStroke/v_BreastStroke_g24_c01.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g09_c03.avi
# Error: Could not read frame 88 from ./train/BreastStroke/v_BreastStroke_g09_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g16_c02.avi
# Error: Could not read frame 237 from ./train/BreastStroke/v_BreastStroke_g16_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g13_c03.avi
# Error: Could not read frame 68 from ./train/BreastStroke/v_BreastStroke_g13_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g06_c01.avi
# Error: Could not read frame 117 from ./train/BreastStroke/v_BreastStroke_g06_c01.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g15_c04.avi
# Error: Could not read frame 122 from ./train/BreastStroke/v_BreastStroke_g15_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g04_c03.avi
# Error: Could not read frame 193 from ./train/BreastStroke/v_BreastStroke_g04_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g09_c04.avi
# Error: Could not read frame 94 from ./train/BreastStroke/v_BreastStroke_g09_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g03_c02.avi
# Error: Could not read frame 180 from ./train/BreastStroke/v_BreastStroke_g03_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g10_c02.avi
# Error: Could not read frame 193 from ./train/BreastStroke/v_BreastStroke_g10_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g25_c03.avi
# Error: Could not read frame 152 from ./train/BreastStroke/v_BreastStroke_g25_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g20_c02.avi
# Error: Could not read frame 143 from ./train/BreastStroke/v_BreastStroke_g20_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g01_c03.avi
# Error: Could not read frame 97 from ./train/BreastStroke/v_BreastStroke_g01_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g06_c04.avi
# Error: Could not read frame 115 from ./train/BreastStroke/v_BreastStroke_g06_c04.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g23_c02.avi
# Error: Could not read frame 359 from ./train/BreastStroke/v_BreastStroke_g23_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g16_c03.avi
# Error: Could not read frame 223 from ./train/BreastStroke/v_BreastStroke_g16_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g07_c02.avi
# Error: Could not read frame 306 from ./train/BreastStroke/v_BreastStroke_g07_c02.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g18_c03.avi
# Error: Could not read frame 159 from ./train/BreastStroke/v_BreastStroke_g18_c03.avi
# Processing train video file: ./train/BreastStroke/v_BreastStroke_g16_c01.avi
# Error: Could not read frame 252 from ./train/BreastStroke/v_BreastStroke_g16_c01.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g07_c02.avi
# Error: Could not read frame 102 from ./train/TableTennisShot/v_TableTennisShot_g07_c02.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g13_c03.avi
# Error: Could not read frame 126 from ./train/TableTennisShot/v_TableTennisShot_g13_c03.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g09_c03.avi
# Error: Could not read frame 78 from ./train/TableTennisShot/v_TableTennisShot_g09_c03.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g10_c04.avi
# Error: Could not read frame 134 from ./train/TableTennisShot/v_TableTennisShot_g10_c04.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g06_c04.avi
# Error: Could not read frame 112 from ./train/TableTennisShot/v_TableTennisShot_g06_c04.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g03_c04.avi
# Error: Could not read frame 132 from ./train/TableTennisShot/v_TableTennisShot_g03_c04.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g07_c04.avi
# Error: Could not read frame 81 from ./train/TableTennisShot/v_TableTennisShot_g07_c04.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g14_c04.avi
# Error: Could not read frame 251 from ./train/TableTennisShot/v_TableTennisShot_g14_c04.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g02_c04.avi
# Error: Could not read frame 120 from ./train/TableTennisShot/v_TableTennisShot_g02_c04.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g24_c03.avi
# Error: Could not read frame 251 from ./train/TableTennisShot/v_TableTennisShot_g24_c03.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g21_c03.avi
# Error: Could not read frame 76 from ./train/TableTennisShot/v_TableTennisShot_g21_c03.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g09_c06.avi
# Error: Could not read frame 119 from ./train/TableTennisShot/v_TableTennisShot_g09_c06.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g22_c02.avi
# Error: Could not read frame 204 from ./train/TableTennisShot/v_TableTennisShot_g22_c02.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g09_c01.avi
# Error: Could not read frame 101 from ./train/TableTennisShot/v_TableTennisShot_g09_c01.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g07_c03.avi
# Error: Could not read frame 77 from ./train/TableTennisShot/v_TableTennisShot_g07_c03.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g01_c02.avi
# Error: Could not read frame 170 from ./train/TableTennisShot/v_TableTennisShot_g01_c02.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g08_c02.avi
# Error: Could not read frame 52 from ./train/TableTennisShot/v_TableTennisShot_g08_c02.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g01_c05.avi
# Error: Could not read frame 165 from ./train/TableTennisShot/v_TableTennisShot_g01_c05.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g20_c07.avi
# Error: Could not read frame 148 from ./train/TableTennisShot/v_TableTennisShot_g20_c07.avi
# Processing train video file: ./train/TableTennisShot/v_TableTennisShot_g21_c04.avi
# Error: Could not read frame 58 from ./train/TableTennisShot/v_TableTennisShot_g21_c04.avi
# Processing test video file: ./test/Swing/v_Swing_g21_c02.avi
# Error: Could not read frame 169 from ./test/Swing/v_Swing_g21_c02.avi
# Processing test video file: ./test/Swing/v_Swing_g21_c06.avi
# Error: Could not read frame 202 from ./test/Swing/v_Swing_g21_c06.avi
# Processing test video file: ./test/Swing/v_Swing_g21_c04.avi
# Error: Could not read frame 152 from ./test/Swing/v_Swing_g21_c04.avi
# Processing test video file: ./test/Swing/v_Swing_g20_c06.avi
# Error: Could not read frame 152 from ./test/Swing/v_Swing_g20_c06.avi
# Processing test video file: ./test/Swing/v_Swing_g14_c02.avi
# Error: Could not read frame 152 from ./test/Swing/v_Swing_g14_c02.avi
# Processing test video file: ./test/Swing/v_Swing_g04_c05.avi
# Error: Could not read frame 152 from ./test/Swing/v_Swing_g04_c05.avi
# Processing test video file: ./test/Swing/v_Swing_g12_c03.avi
# Error: Could not read frame 127 from ./test/Swing/v_Swing_g12_c03.avi
# Processing test video file: ./test/Swing/v_Swing_g19_c01.avi
# Error: Could not read frame 277 from ./test/Swing/v_Swing_g19_c01.avi
# Processing test video file: ./test/Swing/v_Swing_g20_c05.avi
# Error: Could not read frame 152 from ./test/Swing/v_Swing_g20_c05.avi
# Processing test video file: ./test/Swing/v_Swing_g04_c04.avi
# Error: Could not read frame 169 from ./test/Swing/v_Swing_g04_c04.avi
# Processing test video file: ./test/Swing/v_Swing_g20_c01.avi
# Error: Could not read frame 152 from ./test/Swing/v_Swing_g20_c01.avi
# Processing test video file: ./test/Swing/v_Swing_g19_c03.avi
# Error: Could not read frame 277 from ./test/Swing/v_Swing_g19_c03.avi
# Processing test video file: ./test/Swing/v_Swing_g23_c01.avi
# Error: Could not read frame 127 from ./test/Swing/v_Swing_g23_c01.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g19_c01.avi
# Error: Could not read frame 210 from ./test/BreastStroke/v_BreastStroke_g19_c01.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g20_c01.avi
# Error: Could not read frame 143 from ./test/BreastStroke/v_BreastStroke_g20_c01.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g10_c03.avi
# Error: Could not read frame 193 from ./test/BreastStroke/v_BreastStroke_g10_c03.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g13_c01.avi
# Error: Could not read frame 68 from ./test/BreastStroke/v_BreastStroke_g13_c01.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g08_c01.avi
# Error: Could not read frame 216 from ./test/BreastStroke/v_BreastStroke_g08_c01.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g11_c02.avi
# Error: Could not read frame 364 from ./test/BreastStroke/v_BreastStroke_g11_c02.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g22_c04.avi
# Error: Could not read frame 333 from ./test/BreastStroke/v_BreastStroke_g22_c04.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g04_c02.avi
# Error: Could not read frame 184 from ./test/BreastStroke/v_BreastStroke_g04_c02.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g17_c04.avi
# Error: Could not read frame 107 from ./test/BreastStroke/v_BreastStroke_g17_c04.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g20_c04.avi
# Error: Could not read frame 157 from ./test/BreastStroke/v_BreastStroke_g20_c04.avi
# Processing test video file: ./test/BreastStroke/v_BreastStroke_g01_c02.avi
# Error: Could not read frame 97 from ./test/BreastStroke/v_BreastStroke_g01_c02.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g02_c03.avi
# Error: Could not read frame 146 from ./test/TableTennisShot/v_TableTennisShot_g02_c03.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g23_c03.avi
# Error: Could not read frame 256 from ./test/TableTennisShot/v_TableTennisShot_g23_c03.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g16_c03.avi
# Error: Could not read frame 255 from ./test/TableTennisShot/v_TableTennisShot_g16_c03.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g19_c02.avi
# Error: Could not read frame 255 from ./test/TableTennisShot/v_TableTennisShot_g19_c02.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g25_c07.avi
# Error: Could not read frame 352 from ./test/TableTennisShot/v_TableTennisShot_g25_c07.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g23_c02.avi
# Error: Could not read frame 228 from ./test/TableTennisShot/v_TableTennisShot_g23_c02.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g05_c04.avi
# Error: Could not read frame 177 from ./test/TableTennisShot/v_TableTennisShot_g05_c04.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g05_c07.avi
# Error: Could not read frame 158 from ./test/TableTennisShot/v_TableTennisShot_g05_c07.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g23_c01.avi
# Error: Could not read frame 224 from ./test/TableTennisShot/v_TableTennisShot_g23_c01.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g04_c07.avi
# Error: Could not read frame 143 from ./test/TableTennisShot/v_TableTennisShot_g04_c07.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g16_c01.avi
# Error: Could not read frame 208 from ./test/TableTennisShot/v_TableTennisShot_g16_c01.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g24_c05.avi
# Error: Could not read frame 208 from ./test/TableTennisShot/v_TableTennisShot_g24_c05.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g09_c05.avi
# Error: Could not read frame 165 from ./test/TableTennisShot/v_TableTennisShot_g09_c05.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g12_c03.avi
# Error: Could not read frame 103 from ./test/TableTennisShot/v_TableTennisShot_g12_c03.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g09_c07.avi
# Error: Could not read frame 77 from ./test/TableTennisShot/v_TableTennisShot_g09_c07.avi
# Processing test video file: ./test/TableTennisShot/v_TableTennisShot_g04_c06.avi
# Error: Could not read frame 212 from ./test/TableTennisShot/v_TableTennisShot_g04_c06.avi

# %%
df_train = pd.read_csv('./train_coords.csv')
df_test = pd.read_csv('./test_coords.csv')

# %%
x_train = df_train.drop('class', axis=1)
y_train = df_train['class']
x_test = df_test.drop('class', axis=1)
y_test = df_test['class']

# %%
#before gridsearch
pipelines = {
    # 'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    # 'rc':make_pipeline(StandardScaler(), RidgeClassifier())
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier())
    # 'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
    # 'knn':make_pipeline(StandardScaler(), KNeighborsClassifier()),
    # 'xgb':make_pipeline(StandardScaler(), xgb.XGBClassifier()),
}

# %%
    #after gridsearch
    pipelines = {
        # 'lr':make_pipeline(StandardScaler(), LogisticRegression(C=0.1, penalty='l2', solver='liblinear')),
        # 'rc':make_pipeline(StandardScaler(), RidgeClassifier(alpha=10))
        'rf':make_pipeline(StandardScaler(), RandomForestClassifier(max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50)),
        # 'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier(learning_rate=0.1, max_depth=5, n_estimators=200)),
    }

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, f1_score

# Assuming pipelines is a dictionary of algorithms and their pipelines
fit_models = {}
for algo, pipeline in pipelines.items():
    print(f"Training pipeline for: {algo}")

    if x_train.shape[0] == 0 or y_train.shape[0] == 0:
        print(f"Error: No training data for {algo}. Skipping...")
        continue

    try:
        # Perform cross-validation to reduce overfitting
        scores = cross_val_score(pipeline, x_train, y_train, cv=5, scoring='accuracy')
        print(f"Cross-Validation Accuracy for {algo}: {scores.mean():.4f} ± {scores.std():.4f}")

        # Fit the pipeline on the full training data
        model = pipeline.fit(x_train, y_train)
        fit_models[algo] = model
        print(f"Successfully trained {algo}")
    except Exception as e:
        print(f"Error training {algo}: {e}")

# Evaluate models
for algo, model in fit_models.items():
    print(f"Evaluating model for: {algo}")

    # Training metrics
    yhat_train = model.predict(x_train)
    train_accuracy = accuracy_score(y_train, yhat_train)
    train_precision = precision_score(y_train, yhat_train, average='weighted')
    train_f1 = f1_score(y_train, yhat_train, average='weighted')
    print(f"{algo} - Training Accuracy: {train_accuracy:.4f}, Precision: {train_precision:.4f}, F1-Score: {train_f1:.4f}")

    # Testing metrics
    yhat = model.predict(x_test)
    test_accuracy = accuracy_score(y_test, yhat)
    test_precision = precision_score(y_test, yhat, average='weighted')
    test_f1 = f1_score(y_test, yhat, average='weighted')
    print(f"{algo} - Test Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, F1-Score: {test_f1:.4f}")

    # Overfitting warning
    if train_accuracy - test_accuracy > 0.1:
        print(f"Warning: {algo} might be overfitting (Train-Test Gap > 10%)")
# Out:
# Training pipeline for: rf
# Cross-Validation Accuracy for rf: 0.8002 ± 0.0821
# Successfully trained rf
# Evaluating model for: rf
# rf - Training Accuracy: 0.9991, Precision: 0.9991, F1-Score: 0.9991
# rf - Test Accuracy: 0.7210, Precision: 0.7858, F1-Score: 0.7342
# Warning: rf might be overfitting (Train-Test Gap > 10%)

# %%
with open('limb_detection.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
with open('limb_detection.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
# %pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.9.1-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting anyio<5.0,>=3.0 (from gradio)
#   Downloading anyio-4.7.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.5.2 (from gradio)
#   Downloading gradio_client-1.5.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub>=0.25.1 (from gradio)
#   Downloading huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting jinja2<4.0 (from gradio)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting markupsafe~=2.0 (from gradio)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\devin\appdata\local\programs\python\python311\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.12-cp311-none-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: packaging in c:\users\devin\appdata\roaming\python\python311\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\devin\appdata\local\programs\python\python311\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\devin\appdata\local\programs\python\python311\lib\site-packages (from gradio) (11.0.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting pyyaml<7.0,>=5.0 (from gradio)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.8.4-py3-none-win_amd64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.42.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\devin\appdata\roaming\python\python311\site-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting fsspec (from gradio-client==1.5.2->gradio)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting websockets<15.0,>=10.0 (from gradio-client==1.5.2->gradio)
#   Downloading websockets-14.1-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting idna>=2.8 (from anyio<5.0,>=3.0->gradio)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting sniffio>=1.1 (from anyio<5.0,>=3.0->gradio)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting certifi (from httpx>=0.24.1->gradio)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting filelock (from huggingface-hub>=0.25.1->gradio)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests (from huggingface-hub>=0.25.1->gradio)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.25.1->gradio)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devin\appdata\roaming\python\python311\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devin\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\users\devin\appdata\roaming\python\python311\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\devin\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\devin\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub>=0.25.1->gradio)
#   Downloading charset_normalizer-3.4.0-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub>=0.25.1->gradio)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-5.9.1-py3-none-any.whl (57.2 MB)
#    ---------------------------------------- 0.0/57.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/57.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/57.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/57.2 MB ? eta -:--:--
#     --------------------------------------- 0.8/57.2 MB 1.5 MB/s eta 0:00:39
#     --------------------------------------- 1.0/57.2 MB 1.4 MB/s eta 0:00:41
#     --------------------------------------- 1.3/57.2 MB 1.3 MB/s eta 0:00:44
#    - -------------------------------------- 1.8/57.2 MB 1.3 MB/s eta 0:00:42
#    - -------------------------------------- 1.8/57.2 MB 1.3 MB/s eta 0:00:42
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading websockets-14.1-cp311-cp311-win_amd64.whl (163 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.0-cp311-cp311-win_amd64.whl (101 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pydub, websockets, urllib3, tqdm, tomlkit, sniffio, shellingham, semantic-version, ruff, pyyaml, python-multipart, pydantic-core, orjson, mdurl, markupsafe, idna, h11, fsspec, filelock, ffmpy, click, charset-normalizer, certifi, annotated-types, aiofiles, uvicorn, requests, pydantic, markdown-it-py, jinja2, httpcore, anyio, starlette, rich, huggingface-hub, httpx, typer, safehttpx, gradio-client, fastapi, gradio
# Successfully installed aiofiles-23.2.1 annotated-types-0.7.0 anyio-4.7.0 certifi-2024.12.14 charset-normalizer-3.4.0 click-8.1.8 fastapi-0.115.6 ffmpy-0.5.0 filelock-3.16.1 fsspec-2024.12.0 gradio-5.9.1 gradio-client-1.5.2 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 huggingface-hub-0.27.0 idna-3.10 jinja2-3.1.5 markdown-it-py-3.0.0 markupsafe-2.1.5 mdurl-0.1.2 orjson-3.10.12 pydantic-2.10.4 pydantic-core-2.27.2 pydub-0.25.1 python-multipart-0.0.20 pyyaml-6.0.2 requests-2.32.3 rich-13.9.4 ruff-0.8.4 safehttpx-0.1.6 semantic-version-2.10.0 shellingham-1.5.4 sniffio-1.3.1 starlette-0.41.3 tomlkit-0.13.2 tqdm-4.67.1 typer-0.15.1 urllib3-2.3.0 uvicorn-0.34.0 websockets-14.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fastapi.exe is installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts gradio.exe and upload_theme.exe are installed in 'c:\Users\devin\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import gradio as gr

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def test_videos(dataset, amount):
    # Initialize the Holistic model
    with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
        for i in range(min(len(dataset), amount)):
            video_path = dataset['clip_path'].iloc[i]
            class_name = dataset['label'].iloc[i]

            cap = cv2.VideoCapture(video_path)

            if not cap.isOpened():
                print(f"Error: Could not open video file {video_path}")
                continue  # Skip to the next video file if there is an error

            print(f"Processing video: {video_path} ({class_name})")
            frame_count = 0

            while cap.isOpened():
                ret, frame = cap.read()
                if not ret or frame is None:
                    print(f"End of video or error reading frame {frame_count} from {video_path}")
                    break

                frame_count += 1
                try:
                    # Resize frame
                    frame = cv2.resize(frame, (640, 480))

                    # Convert to uint8 if necessary
                    if frame.dtype != np.uint8:
                        frame = (frame * 255).astype(np.uint8)

                    # Apply Median Blur
                    frame = cv2.medianBlur(frame, 5)

                    # Convert to grayscale and apply Histogram Equalization
                    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                    equalized_frame = cv2.equalizeHist(gray_frame)
                    frame = cv2.cvtColor(equalized_frame, cv2.COLOR_GRAY2BGR)

                    # Convert to RGB for MediaPipe
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    image.flags.writeable = False

                    # Process the frame with MediaPipe Holistic
                    results = holistic.process(image)
                    image.flags.writeable = True
                    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

                    # Draw pose landmarks if present
                    if results.pose_landmarks:
                        mp_drawing.draw_landmarks(
                            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                        )

                        # Extract pose landmarks
                        try:
                            pose = results.pose_landmarks.landmark
                            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                            x = pd.DataFrame([pose_row])
                            body_language_class = model.predict(x)[0]
                            body_language_prob = model.predict_proba(x)[0]
                            print(f"Class: {body_language_class}, Probability: {body_language_prob}")

                            # Annotate the frame
                            cv2.putText(image, f'Class: {body_language_class}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
                            cv2.putText(image, f'Probability: {body_language_prob[np.argmax(body_language_prob)]:.2f}', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
                        except Exception as e:
                            print(f"Error extracting pose landmarks: {e}")

                    # Display the video frame
                    cv2.imshow('Processed Video Feed', image)

                    # Break the loop on 'q' key press
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break
                except cv2.error as e:
                    print(f"OpenCV error at frame {frame_count}: {e}")
                    break

            cap.release()
            print(f"Finished processing video: {video_path}")

    cv2.destroyAllWindows()

def gradio_interface():
    return test_videos(dataset_test, 20)

iface = gr.Interface(
    fn=gradio_interface,
    inputs=None,
    outputs=gr.Video(label="Labelled Video"),
    live=True,
    description="Click the button to process the video."
)

iface.launch()

# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
import gradio as gr

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def test_videos(dataset, amount):
    # Initialize the Holistic model
    with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
        for i in range(min(len(dataset), amount)):
            video_path = dataset['clip_path'].iloc[i]
            class_name = dataset['label'].iloc[i]

            cap = cv2.VideoCapture(video_path)

            if not cap.isOpened():
                print(f"Error: Could not open video file {video_path}")
                continue  # Skip to the next video file if there is an error

            print(f"Processing video: {video_path} ({class_name})")
            frame_count = 0

            while cap.isOpened():
                ret, frame = cap.read()
                if not ret or frame is None:
                    print(f"End of video or error reading frame {frame_count} from {video_path}")
                    break

                frame_count += 1
                try:
                    # Resize frame
                    frame = cv2.resize(frame, (640, 480))

                    # Convert to uint8 if necessary
                    if frame.dtype != np.uint8:
                        frame = (frame * 255).astype(np.uint8)

                    # Apply Median Blur
                    frame = cv2.medianBlur(frame, 5)
                
                    # Convert to RGB for MediaPipe
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    image.flags.writeable = False

                    # Process the frame with MediaPipe Holistic
                    results = holistic.process(image)
                    image.flags.writeable = True
                    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

                    # Draw pose landmarks if present
                    if results.pose_landmarks:
                        mp_drawing.draw_landmarks(
                            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                        )

                        # Extract pose landmarks
                        try:
                            pose = results.pose_landmarks.landmark
                            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                            x = pd.DataFrame([pose_row])
                            body_language_class = model.predict(x)[0]
                            body_language_prob = model.predict_proba(x)[0]
                            print(f"Class: {body_language_class}, Probability: {body_language_prob}")

                            # Annotate the frame
                            cv2.putText(image, f'Class: {body_language_class}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
                            cv2.putText(image, f'Probability: {body_language_prob[np.argmax(body_language_prob)]:.2f}', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
                        except Exception as e:
                            print(f"Error extracting pose landmarks: {e}")

                    # Display the video frame
                    cv2.imshow('Processed Video Feed', image)

                    # Break the loop on 'q' key press
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break
                except cv2.error as e:
                    print(f"OpenCV error at frame {frame_count}: {e}")
                    break

            cap.release()
            print(f"Finished processing video: {video_path}")

    cv2.destroyAllWindows()

# Call the function with a dataset and the desired amount
def gradio_interface():
    return test_videos(dataset_test, 20)

iface = gr.Interface(
    fn=gradio_interface,
    inputs=None,
    outputs=gr.Video(label="Labelled Video"),
    live=True,
    description="Click the button to process the video."
)

iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Processing video: ./test/Swing/v_Swing_g21_c02.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.21699567 0.10416667 0.50064719 0.17819048]
# Class: Swing, Probability: [0.14472294 0.16962121 0.52928355 0.15637229]
# Class: Swing, Probability: [0.09472294 0.18295455 0.56595022 0.15637229]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.10672294 0.10166667 0.49402597 0.29758442]
# Class: Swing, Probability: [0.08638961 0.11774892 0.59938817 0.1964733 ]
# Class: Swing, Probability: [0.05657143 0.07833333 0.72952381 0.13557143]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.02277778 0.06588889 0.634      0.27733333]
# Class: Swing, Probability: [0.16644251 0.14889502 0.4845831  0.20007937]
# Class: Swing, Probability: [0.01022222 0.06       0.86377778 0.066     ]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.00222222 0.02       0.94577778 0.032     ]
# Class: Swing, Probability: [0.06125    0.156915   0.49613492 0.28570008]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.28609091 0.1936044  0.40214308 0.11816162]
# Class: Swing, Probability: [0.24560606 0.2370974  0.42456926 0.09272727]
# Class: Swing, Probability: [0.31160606 0.20555894 0.39210773 0.09072727]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: BreastStroke, Probability: [0.38160606 0.13914286 0.37397835 0.10527273]
# Class: BreastStroke, Probability: [0.40127273 0.122      0.34278788 0.13393939]
# Class: BreastStroke, Probability: [0.41031373 0.122      0.36768627 0.1       ]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.29989177 0.142      0.3508355  0.20727273]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: BreastStroke, Probability: [0.36132035 0.20914286 0.26226407 0.16727273]
# Class: BreastStroke, Probability: [0.41265368 0.18789411 0.26472494 0.13472727]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: BreastStroke, Probability: [0.38132035 0.22789411 0.29805828 0.09272727]
# Class: BreastStroke, Probability: [0.33308225 0.17942491 0.26022011 0.22727273]
# Class: Swing, Probability: [0.20698701 0.16018681 0.38355345 0.24927273]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.21127273 0.20755861 0.35189594 0.22927273]
# Class: Swing, Probability: [0.11073304 0.16078525 0.54992327 0.17855844]
# Class: Swing, Probability: [0.2028195  0.15275902 0.32564876 0.31877273]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.08723277 0.70562826 0.19382728 0.01331169]
# Class: SkyDiving, Probability: [0.07450549 0.82027473 0.09736264 0.00785714]
# Class: SkyDiving, Probability: [0.18204157 0.43065279 0.31298529 0.07432035]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.21189222 0.30699797 0.38250375 0.09860606]
# Class: Swing, Probability: [0.17294783 0.15217766 0.56170901 0.1131655 ]
# Class: SkyDiving, Probability: [0.27966667 0.53343651 0.14689683 0.04      ]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.25078766 0.22713187 0.4422825  0.07979798]
# Class: Swing, Probability: [0.23558619 0.23822727 0.39826229 0.12792424]
# Class: Swing, Probability: [0.20687302 0.23940981 0.46066667 0.09305051]
# Finished processing video: ./test/Swing/v_Swing_g21_c02.avi
# Processing video: ./test/Swing/v_Swing_g21_c06.avi (Swing)
# Class: BreastStroke, Probability: [0.44643007 0.13454545 0.30635781 0.11266667]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.31478022 0.20398535 0.39672161 0.08451282]
# Class: Swing, Probability: [0.33779358 0.20639194 0.39837858 0.0574359 ]
# Finished processing video: ./test/Swing/v_Swing_g21_c06.avi
# Processing video: ./test/Swing/v_Swing_g21_c04.avi (Swing)
# Class: Swing, Probability: [0.16350564 0.22751515 0.42591138 0.18306782]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.14861676 0.12618182 0.50657805 0.21862338]
# Class: Swing, Probability: [0.12541414 0.14618182 0.50978066 0.21862338]
# Class: Swing, Probability: [0.12430303 0.13618182 0.48889177 0.25062338]
# Finished processing video: ./test/Swing/v_Swing_g21_c04.avi
# Processing video: ./test/Swing/v_Swing_g20_c06.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g20_c06.avi
# Processing video: ./test/Swing/v_Swing_g14_c02.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.19425902 0.30961255 0.48362843 0.0125    ]
# Class: Swing, Probability: [0.17825902 0.27460275 0.51713823 0.03      ]
# Class: SkyDiving, Probability: [0.17764763 0.53901584 0.28333653 0.        ]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.08638889 0.5006993  0.40791181 0.005     ]
# Finished processing video: ./test/Swing/v_Swing_g14_c02.avi
# Processing video: ./test/Swing/v_Swing_g04_c05.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g04_c05.avi
# Processing video: ./test/Swing/v_Swing_g12_c03.avi (Swing)
# Class: Swing, Probability: [0.12217532 0.13607143 0.73084416 0.01090909]
# Finished processing video: ./test/Swing/v_Swing_g12_c03.avi
# Processing video: ./test/Swing/v_Swing_g19_c01.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g19_c01.avi
# Processing video: ./test/Swing/v_Swing_g20_c05.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g20_c05.avi
# Processing video: ./test/Swing/v_Swing_g04_c04.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g04_c04.avi
# Processing video: ./test/Swing/v_Swing_g20_c01.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g20_c01.avi
# Processing video: ./test/Swing/v_Swing_g19_c03.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g19_c03.avi
# Processing video: ./test/Swing/v_Swing_g23_c01.avi (Swing)
# Class: Swing, Probability: [0.06733333 0.04944444 0.82738889 0.05583333]
# Class: Swing, Probability: [0.10484848 0.02181818 0.81333333 0.06      ]
# Finished processing video: ./test/Swing/v_Swing_g23_c01.avi
# Processing video: ./test/Swing/v_Swing_g11_c04.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.01188312 0.08061688 0.8775     0.03      ]
# Class: Swing, Probability: [0.01       0.045      0.93590909 0.00909091]
# Class: Swing, Probability: [0.         0.025      0.94590909 0.02909091]
# Finished processing video: ./test/Swing/v_Swing_g11_c04.avi
# Processing video: ./test/Swing/v_Swing_g01_c02.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g01_c02.avi
# Processing video: ./test/Swing/v_Swing_g04_c03.avi (Swing)
# Class: Swing, Probability: [0.07204545 0.22750672 0.68155894 0.01888889]
# Class: Swing, Probability: [0.09035714 0.34479426 0.52095971 0.04388889]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.08392857 0.42299206 0.44919048 0.04388889]
# Finished processing video: ./test/Swing/v_Swing_g04_c03.avi
# Processing video: ./test/Swing/v_Swing_g12_c01.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.00666667 0.11833333 0.875      0.        ]
# Finished processing video: ./test/Swing/v_Swing_g12_c01.avi
# Processing video: ./test/SkyDiving/v_SkyDiving_g16_c03.avi (SkyDiving)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.06830614 0.41218376 0.46122222 0.05828788]
# Class: Swing, Probability: [0.03487179 0.31218881 0.60331818 0.04962121]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.06333333 0.21266667 0.64468182 0.07931818]
# Class: Swing, Probability: [0.05       0.336      0.53668182 0.07731818]
# Class: Swing, Probability: [0.05       0.39980952 0.40620563 0.14398485]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.05       0.43422222 0.32734848 0.18842929]
# Class: SkyDiving, Probability: [0.05       0.44694949 0.35098485 0.15206566]
# Class: SkyDiving, Probability: [0.04       0.44306061 0.34709596 0.16984343]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.03       0.53575902 0.2999531  0.13428788]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.07333333 0.47969841 0.29631674 0.15065152]
# Class: SkyDiving, Probability: [0.06       0.48255556 0.3109596  0.14648485]
# Class: SkyDiving, Probability: [0.05444444 0.442      0.3059596  0.19759596]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.05       0.49755556 0.2659596  0.18648485]
# Class: SkyDiving, Probability: [0.02153846 0.61601709 0.17777778 0.18466667]
# Class: SkyDiving, Probability: [0.02       0.69755556 0.13333333 0.14911111]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.03       0.67755556 0.14333333 0.14911111]
# Class: SkyDiving, Probability: [0.03       0.662      0.12333333 0.18466667]
# Class: SkyDiving, Probability: [0.03153846 0.65601709 0.14333333 0.16911111]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.03153846 0.70101709 0.13666667 0.13077778]
# Class: SkyDiving, Probability: [0.03153846 0.71374437 0.12030303 0.13441414]
# Class: SkyDiving, Probability: [0.014      0.75906061 0.13030303 0.09663636]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.014      0.83633333 0.09666667 0.053     ]
# Class: SkyDiving, Probability: [0.01553846 0.91146154 0.025      0.048     ]
# Class: SkyDiving, Probability: [0.014 0.928 0.01  0.048]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.004      0.88133333 0.05166667 0.063     ]
# Class: SkyDiving, Probability: [0.014      0.81406061 0.10030303 0.07163636]
# Class: SkyDiving, Probability: [0.014      0.81406061 0.10030303 0.07163636]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.014      0.76906061 0.13030303 0.08663636]
# Class: SkyDiving, Probability: [0.014      0.78906061 0.11030303 0.08663636]
# Class: SkyDiving, Probability: [0.005      0.75539394 0.08630303 0.15330303]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.01166667 0.706      0.10766667 0.17466667]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.01142857 0.88447619 0.04842857 0.05566667]
# Class: SkyDiving, Probability: [0.06892857 0.80114286 0.06092857 0.069     ]
# Class: SkyDiving, Probability: [0.03142857 0.88447619 0.04842857 0.03566667]
# Class: SkyDiving, Probability: [0.01142857 0.83514286 0.05442857 0.099     ]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.01142857 0.82014286 0.08442857 0.084     ]
# Class: SkyDiving, Probability: [0.01       0.83633333 0.093      0.06066667]
# Class: SkyDiving, Probability: [0.01       0.89233333 0.067      0.03066667]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.01  0.914 0.052 0.024]
# Class: SkyDiving, Probability: [0.03446429 0.91525    0.04628571 0.004     ]
# Class: SkyDiving, Probability: [0.004 0.97  0.026 0.   ]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: SkyDiving, Probability: [0.    0.969 0.031 0.   ]
# Finished processing video: ./test/SkyDiving/v_SkyDiving_g16_c03.avi
# Processing video: ./test/SkyDiving/v_SkyDiving_g25_c04.avi (SkyDiving)
# Finished processing video: ./test/SkyDiving/v_SkyDiving_g25_c04.avi
# Processing video: ./test/SkyDiving/v_SkyDiving_g14_c01.avi (SkyDiving)
# Finished processing video: ./test/SkyDiving/v_SkyDiving_g14_c01.avi
# Processing video: ./test/Swing/v_Swing_g21_c02.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.21699567 0.10416667 0.50064719 0.17819048]
# Class: Swing, Probability: [0.14472294 0.16962121 0.52928355 0.15637229]
# Class: Swing, Probability: [0.09472294 0.18295455 0.56595022 0.15637229]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.10672294 0.10166667 0.49402597 0.29758442]
# Class: Swing, Probability: [0.08638961 0.11774892 0.59938817 0.1964733 ]
# Class: Swing, Probability: [0.05657143 0.07833333 0.72952381 0.13557143]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.02277778 0.06588889 0.634      0.27733333]
# Finished processing video: ./test/Swing/v_Swing_g21_c02.avi
# Processing video: ./test/Swing/v_Swing_g21_c06.avi (Swing)
# Class: Swing, Probability: [0.08415152 0.11366667 0.5097013  0.29248052]
# Class: Swing, Probability: [0.06781818 0.15010606 0.61108225 0.17099351]
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.06063492 0.09184127 0.72047619 0.12704762]
# Class: Swing, Probability: [0.00837607 0.02272727 0.72955983 0.23933683]
# Finished processing video: ./test/Swing/v_Swing_g21_c06.avi
# Processing video: ./test/Swing/v_Swing_g21_c04.avi (Swing)
# Class: TableTennisShot, Probability: [0.01863636 0.05484848 0.43989177 0.48662338]
# Finished processing video: ./test/Swing/v_Swing_g21_c04.avi
# Processing video: ./test/Swing/v_Swing_g20_c06.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g20_c06.avi
# Processing video: ./test/Swing/v_Swing_g14_c02.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g14_c02.avi
# Processing video: ./test/Swing/v_Swing_g04_c05.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g04_c05.avi
# Processing video: ./test/Swing/v_Swing_g12_c03.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.00181818 0.16874359 0.6190692  0.21036903]
# Finished processing video: ./test/Swing/v_Swing_g12_c03.avi
# Processing video: ./test/Swing/v_Swing_g19_c01.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g19_c01.avi
# Processing video: ./test/Swing/v_Swing_g20_c05.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g20_c05.avi
# Processing video: ./test/Swing/v_Swing_g04_c04.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g04_c04.avi
# Processing video: ./test/Swing/v_Swing_g20_c01.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g20_c01.avi
# Processing video: ./test/Swing/v_Swing_g19_c03.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g19_c03.avi
# Processing video: ./test/Swing/v_Swing_g23_c01.avi (Swing)
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Class: Swing, Probability: [0.04       0.07405983 0.60760684 0.27833333]
# Finished processing video: ./test/Swing/v_Swing_g23_c01.avi
# Processing video: ./test/Swing/v_Swing_g11_c04.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g11_c04.avi
# Processing video: ./test/Swing/v_Swing_g01_c02.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g01_c02.avi
# Processing video: ./test/Swing/v_Swing_g04_c03.avi (Swing)
# Class: Swing, Probability: [0.07204545 0.19084005 0.63822561 0.09888889]
# Finished processing video: ./test/Swing/v_Swing_g04_c03.avi
# Processing video: ./test/Swing/v_Swing_g12_c01.avi (Swing)
# Finished processing video: ./test/Swing/v_Swing_g12_c01.avi
# Processing video: ./test/SkyDiving/v_SkyDiving_g16_c03.avi (SkyDiving)
# Finished processing video: ./test/SkyDiving/v_SkyDiving_g16_c03.avi
# Processing video: ./test/SkyDiving/v_SkyDiving_g25_c04.avi (SkyDiving)
# Finished processing video: ./test/SkyDiving/v_SkyDiving_g25_c04.avi
# Processing video: ./test/SkyDiving/v_SkyDiving_g14_c01.avi (SkyDiving)
# Finished processing video: ./test/SkyDiving/v_SkyDiving_g14_c01.avi

# %%
import gradio as gr
import cv2
import numpy as np
import mediapipe as mp
import tempfile
import os

# Mediapipe setup
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# Function to convert avi to mp4
def convert_avi_to_mp4(avi_file):
    # Create a temporary file for the output mp4
    temp_mp4_path = tempfile.mktemp(suffix=".mp4")
    cap = cv2.VideoCapture(avi_file.name)
    
    # Check if the video file is opened correctly
    if not cap.isOpened():
        return None
    
    # Get frame width, height, and FPS for video saving
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(temp_mp4_path, fourcc, fps, (width, height))
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        out.write(frame)
    
    cap.release()
    out.release()
    
    return temp_mp4_path

# Function to process video and recognize activity
def recognize_pose(video_file):
    # Convert avi to mp4 (Gradio supports mp4)
    temp_mp4_path = convert_avi_to_mp4(video_file)
    if temp_mp4_path is None:
        return "Error: Unable to process video."

    # Now process the mp4 video
    with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7) as holistic:
        cap = cv2.VideoCapture(temp_mp4_path)
        output_frames = []

        # Check if video is loaded correctly
        if not cap.isOpened():
            return "Error: Unable to read the video."

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # Resize and preprocess frame
            frame = cv2.resize(frame, (640, 480))
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            # Process frame with Mediapipe
            results = holistic.process(image)

            # If pose landmarks are detected, draw them
            if results.pose_landmarks:
                mp_drawing.draw_landmarks(
                    image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                    mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                )
            else:
                print("No pose landmarks detected in this frame.")

            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # Add processed frame to output frames list
            output_frames.append(image)

        cap.release()

    # Ensure there are frames in the output
    if not output_frames:
        return "Error: No frames processed."

    # Save the processed frames to the temporary video file
    temp_output_path = tempfile.mktemp(suffix=".mp4")
    height, width, layers = output_frames[0].shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Using the MP4 codec
    out = cv2.VideoWriter(temp_output_path, fourcc, 20.0, (width, height))

    for frame in output_frames:
        out.write(frame)
    out.release()

    # Clean up the temporary mp4 conversion file
    os.remove(temp_mp4_path)

    # Return the path to the processed video
    return temp_output_path

# Gradio interface function
def gradio_interface(video):
    result_video = recognize_pose(video)
    return result_video

# Gradio setup
interface = gr.Interface(
    fn=gradio_interface,
    inputs=gr.Video(label="Input Video"),
    outputs=gr.Video(label="Processed Video")
)

# Launch the Gradio app
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 2047, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1594, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 2505, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 1005, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\utils.py", line 869, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\devin\AppData\Local\Temp\ipykernel_24700\4068015304.py", line 108, in gradio_interface
#     result_video = recognize_pose(video)
#                    ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\devin\AppData\Local\Temp\ipykernel_24700\4068015304.py", line 44, in recognize_pose
#     temp_mp4_path = convert_avi_to_mp4(video_file)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\devin\AppData\Local\Temp\ipykernel_24700\4068015304.py", line 16, in convert_avi_to_mp4
#     cap = cv2.VideoCapture(avi_file.name)
#                            ^^^^^^^^^^^^^
# AttributeError: 'str' object has no attribute 'name'
